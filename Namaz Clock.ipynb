# %%
from tkinter import*
import time

clock=Tk()
clock.title("Namaz Clock")
clock.geometry("800x800")
clock.configure(bg="Black")

def tick(time1=""):
    time2 = time.strftime("%I : %M : %S")
    label1.configure(text=time2)
    label1.after(20,tick)


def fajar_namaz():
    label3.configure(text="05:32 a.m. Fajar")
    
def zohar_namaz():
    label4.configure(text="12:17 p.m. Zohar")
    
def asar_namaz():
    label5.configure(text="04:08 p.m. Asar")
    
def maghrib_namaz():
    label6.configure(text="05:43 p.m. Maghrib")
    
def isha_namaz():
    label7.configure(text="07:03 p.m. Isha")
       
def jumma_namaz():
    label8.configure(text="02:00 p.m. Jumma \n\n")
    
    
#Labels

label1=Label(clock, fg="Red", bg="Black" , font='Arial 100 bold')
label1.pack(fill="both", expand=1)

label2=Label(clock, text="NAMAZ TIMINGS", fg="Orange", bg="Black" , font='Arial 40 bold')
label2.pack(fill=X)

label3=Label(clock, fg="White", bg="Black" , font='Arial 35 bold')
label3.pack(fill=X)

label4=Label(clock, fg="White", bg="Black" , font='Arial 35 bold')
label4.pack(fill=X)

label5=Label(clock, fg="White", bg="Black" , font='Arial 35 bold')
label5.pack(fill=X)

label6=Label(clock, fg="White", bg="Black" , font='Arial 35 bold')
label6.pack(fill=X)

label7=Label(clock, fg="White", bg="Black" , font='Arial 35 bold')
label7.pack(fill=X)

label8=Label(clock, fg="White", bg="Black" , font='Arial 35 bold')
label8.pack(fill=X)

tick()
fajar_namaz()
zohar_namaz()
asar_namaz()
maghrib_namaz()
isha_namaz()
jumma_namaz()

clock.mainloop()
